# %% [markdown]
# ### 1. Load the dataset

# %% [markdown]
# **[1.1] Automatic reload modules**

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# **[1.2] Import packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# from joblib import dump

# %% [markdown]
# **[1.3] Load the datasets**

# %%
df_train = pd.read_csv('../data/raw/train.csv', low_memory=False)
df_test = pd.read_csv('../data/raw/test.csv', low_memory=False)

# %% [markdown]
# ### 2. Explore the data

# %% [markdown]
# **[2.1]] Display all columns and rows in dataframe**

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# **[2.2] Descriptive statstics**

# %%
from summarytools import dfSummary
dfSummary(df_train)
# Out:
# <style type="text/css">
# #T_ef05f thead>tr>th {
#   text-align: left;
# }
# #T_ef05f_row0_col0, #T_ef05f_row1_col0, #T_ef05f_row2_col0, #T_ef05f_row3_col0, #T_ef05f_row4_col0, #T_ef05f_row5_col0, #T_ef05f_row6_col0, #T_ef05f_row7_col0, #T_ef05f_row8_col0, #T_ef05f_row9_col0, #T_ef05f_row10_col0, #T_ef05f_row11_col0, #T_ef05f_row12_col0, #T_ef05f_row13_col0, #T_ef05f_row14_col0, #T_ef05f_row15_col0, #T_ef05f_row16_col0, #T_ef05f_row17_col0, #T_ef05f_row18_col0, #T_ef05f_row19_col0, #T_ef05f_row20_col0, #T_ef05f_row21_col0, #T_ef05f_row22_col0, #T_ef05f_row23_col0, #T_ef05f_row24_col0, #T_ef05f_row25_col0, #T_ef05f_row26_col0, #T_ef05f_row27_col0, #T_ef05f_row28_col0, #T_ef05f_row29_col0, #T_ef05f_row30_col0, #T_ef05f_row31_col0, #T_ef05f_row32_col0, #T_ef05f_row33_col0, #T_ef05f_row34_col0, #T_ef05f_row35_col0, #T_ef05f_row36_col0, #T_ef05f_row37_col0, #T_ef05f_row38_col0, #T_ef05f_row39_col0, #T_ef05f_row40_col0, #T_ef05f_row41_col0, #T_ef05f_row42_col0, #T_ef05f_row43_col0, #T_ef05f_row44_col0, #T_ef05f_row45_col0, #T_ef05f_row46_col0, #T_ef05f_row47_col0, #T_ef05f_row48_col0, #T_ef05f_row49_col0, #T_ef05f_row50_col0, #T_ef05f_row51_col0, #T_ef05f_row52_col0, #T_ef05f_row53_col0, #T_ef05f_row54_col0, #T_ef05f_row55_col0, #T_ef05f_row56_col0, #T_ef05f_row57_col0, #T_ef05f_row58_col0, #T_ef05f_row59_col0, #T_ef05f_row60_col0, #T_ef05f_row61_col0, #T_ef05f_row62_col0, #T_ef05f_row63_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_ef05f_row0_col1, #T_ef05f_row1_col1, #T_ef05f_row2_col1, #T_ef05f_row3_col1, #T_ef05f_row4_col1, #T_ef05f_row5_col1, #T_ef05f_row6_col1, #T_ef05f_row7_col1, #T_ef05f_row8_col1, #T_ef05f_row9_col1, #T_ef05f_row10_col1, #T_ef05f_row11_col1, #T_ef05f_row12_col1, #T_ef05f_row13_col1, #T_ef05f_row14_col1, #T_ef05f_row15_col1, #T_ef05f_row16_col1, #T_ef05f_row17_col1, #T_ef05f_row18_col1, #T_ef05f_row19_col1, #T_ef05f_row20_col1, #T_ef05f_row21_col1, #T_ef05f_row22_col1, #T_ef05f_row23_col1, #T_ef05f_row24_col1, #T_ef05f_row25_col1, #T_ef05f_row26_col1, #T_ef05f_row27_col1, #T_ef05f_row28_col1, #T_ef05f_row29_col1, #T_ef05f_row30_col1, #T_ef05f_row31_col1, #T_ef05f_row32_col1, #T_ef05f_row33_col1, #T_ef05f_row34_col1, #T_ef05f_row35_col1, #T_ef05f_row36_col1, #T_ef05f_row37_col1, #T_ef05f_row38_col1, #T_ef05f_row39_col1, #T_ef05f_row40_col1, #T_ef05f_row41_col1, #T_ef05f_row42_col1, #T_ef05f_row43_col1, #T_ef05f_row44_col1, #T_ef05f_row45_col1, #T_ef05f_row46_col1, #T_ef05f_row47_col1, #T_ef05f_row48_col1, #T_ef05f_row49_col1, #T_ef05f_row50_col1, #T_ef05f_row51_col1, #T_ef05f_row52_col1, #T_ef05f_row53_col1, #T_ef05f_row54_col1, #T_ef05f_row55_col1, #T_ef05f_row56_col1, #T_ef05f_row57_col1, #T_ef05f_row58_col1, #T_ef05f_row59_col1, #T_ef05f_row60_col1, #T_ef05f_row61_col1, #T_ef05f_row62_col1, #T_ef05f_row63_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_ef05f_row0_col2, #T_ef05f_row1_col2, #T_ef05f_row2_col2, #T_ef05f_row3_col2, #T_ef05f_row4_col2, #T_ef05f_row5_col2, #T_ef05f_row6_col2, #T_ef05f_row7_col2, #T_ef05f_row8_col2, #T_ef05f_row9_col2, #T_ef05f_row10_col2, #T_ef05f_row11_col2, #T_ef05f_row12_col2, #T_ef05f_row13_col2, #T_ef05f_row14_col2, #T_ef05f_row15_col2, #T_ef05f_row16_col2, #T_ef05f_row17_col2, #T_ef05f_row18_col2, #T_ef05f_row19_col2, #T_ef05f_row20_col2, #T_ef05f_row21_col2, #T_ef05f_row22_col2, #T_ef05f_row23_col2, #T_ef05f_row24_col2, #T_ef05f_row25_col2, #T_ef05f_row26_col2, #T_ef05f_row27_col2, #T_ef05f_row28_col2, #T_ef05f_row29_col2, #T_ef05f_row30_col2, #T_ef05f_row31_col2, #T_ef05f_row32_col2, #T_ef05f_row33_col2, #T_ef05f_row34_col2, #T_ef05f_row35_col2, #T_ef05f_row36_col2, #T_ef05f_row37_col2, #T_ef05f_row38_col2, #T_ef05f_row39_col2, #T_ef05f_row40_col2, #T_ef05f_row41_col2, #T_ef05f_row42_col2, #T_ef05f_row43_col2, #T_ef05f_row44_col2, #T_ef05f_row45_col2, #T_ef05f_row46_col2, #T_ef05f_row47_col2, #T_ef05f_row48_col2, #T_ef05f_row49_col2, #T_ef05f_row50_col2, #T_ef05f_row51_col2, #T_ef05f_row52_col2, #T_ef05f_row53_col2, #T_ef05f_row54_col2, #T_ef05f_row55_col2, #T_ef05f_row56_col2, #T_ef05f_row57_col2, #T_ef05f_row58_col2, #T_ef05f_row59_col2, #T_ef05f_row60_col2, #T_ef05f_row61_col2, #T_ef05f_row62_col2, #T_ef05f_row63_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_ef05f_row0_col3, #T_ef05f_row1_col3, #T_ef05f_row2_col3, #T_ef05f_row3_col3, #T_ef05f_row4_col3, #T_ef05f_row5_col3, #T_ef05f_row6_col3, #T_ef05f_row7_col3, #T_ef05f_row8_col3, #T_ef05f_row9_col3, #T_ef05f_row10_col3, #T_ef05f_row11_col3, #T_ef05f_row12_col3, #T_ef05f_row13_col3, #T_ef05f_row14_col3, #T_ef05f_row15_col3, #T_ef05f_row16_col3, #T_ef05f_row17_col3, #T_ef05f_row18_col3, #T_ef05f_row19_col3, #T_ef05f_row20_col3, #T_ef05f_row21_col3, #T_ef05f_row22_col3, #T_ef05f_row23_col3, #T_ef05f_row24_col3, #T_ef05f_row25_col3, #T_ef05f_row26_col3, #T_ef05f_row27_col3, #T_ef05f_row28_col3, #T_ef05f_row29_col3, #T_ef05f_row30_col3, #T_ef05f_row31_col3, #T_ef05f_row32_col3, #T_ef05f_row33_col3, #T_ef05f_row34_col3, #T_ef05f_row35_col3, #T_ef05f_row36_col3, #T_ef05f_row37_col3, #T_ef05f_row38_col3, #T_ef05f_row39_col3, #T_ef05f_row40_col3, #T_ef05f_row41_col3, #T_ef05f_row42_col3, #T_ef05f_row43_col3, #T_ef05f_row44_col3, #T_ef05f_row45_col3, #T_ef05f_row46_col3, #T_ef05f_row47_col3, #T_ef05f_row48_col3, #T_ef05f_row49_col3, #T_ef05f_row50_col3, #T_ef05f_row51_col3, #T_ef05f_row52_col3, #T_ef05f_row53_col3, #T_ef05f_row54_col3, #T_ef05f_row55_col3, #T_ef05f_row56_col3, #T_ef05f_row57_col3, #T_ef05f_row58_col3, #T_ef05f_row59_col3, #T_ef05f_row60_col3, #T_ef05f_row61_col3, #T_ef05f_row62_col3, #T_ef05f_row63_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_ef05f_row0_col4, #T_ef05f_row1_col4, #T_ef05f_row2_col4, #T_ef05f_row3_col4, #T_ef05f_row4_col4, #T_ef05f_row5_col4, #T_ef05f_row6_col4, #T_ef05f_row7_col4, #T_ef05f_row8_col4, #T_ef05f_row9_col4, #T_ef05f_row10_col4, #T_ef05f_row11_col4, #T_ef05f_row12_col4, #T_ef05f_row13_col4, #T_ef05f_row14_col4, #T_ef05f_row15_col4, #T_ef05f_row16_col4, #T_ef05f_row17_col4, #T_ef05f_row18_col4, #T_ef05f_row19_col4, #T_ef05f_row20_col4, #T_ef05f_row21_col4, #T_ef05f_row22_col4, #T_ef05f_row23_col4, #T_ef05f_row24_col4, #T_ef05f_row25_col4, #T_ef05f_row26_col4, #T_ef05f_row27_col4, #T_ef05f_row28_col4, #T_ef05f_row29_col4, #T_ef05f_row30_col4, #T_ef05f_row31_col4, #T_ef05f_row32_col4, #T_ef05f_row33_col4, #T_ef05f_row34_col4, #T_ef05f_row35_col4, #T_ef05f_row36_col4, #T_ef05f_row37_col4, #T_ef05f_row38_col4, #T_ef05f_row39_col4, #T_ef05f_row40_col4, #T_ef05f_row41_col4, #T_ef05f_row42_col4, #T_ef05f_row43_col4, #T_ef05f_row44_col4, #T_ef05f_row45_col4, #T_ef05f_row46_col4, #T_ef05f_row47_col4, #T_ef05f_row48_col4, #T_ef05f_row49_col4, #T_ef05f_row50_col4, #T_ef05f_row51_col4, #T_ef05f_row52_col4, #T_ef05f_row53_col4, #T_ef05f_row54_col4, #T_ef05f_row55_col4, #T_ef05f_row56_col4, #T_ef05f_row57_col4, #T_ef05f_row58_col4, #T_ef05f_row59_col4, #T_ef05f_row60_col4, #T_ef05f_row61_col4, #T_ef05f_row62_col4, #T_ef05f_row63_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_ef05f_row0_col5, #T_ef05f_row1_col5, #T_ef05f_row2_col5, #T_ef05f_row3_col5, #T_ef05f_row4_col5, #T_ef05f_row5_col5, #T_ef05f_row6_col5, #T_ef05f_row7_col5, #T_ef05f_row8_col5, #T_ef05f_row9_col5, #T_ef05f_row10_col5, #T_ef05f_row11_col5, #T_ef05f_row12_col5, #T_ef05f_row13_col5, #T_ef05f_row14_col5, #T_ef05f_row15_col5, #T_ef05f_row16_col5, #T_ef05f_row17_col5, #T_ef05f_row18_col5, #T_ef05f_row19_col5, #T_ef05f_row20_col5, #T_ef05f_row21_col5, #T_ef05f_row22_col5, #T_ef05f_row23_col5, #T_ef05f_row24_col5, #T_ef05f_row25_col5, #T_ef05f_row26_col5, #T_ef05f_row27_col5, #T_ef05f_row28_col5, #T_ef05f_row29_col5, #T_ef05f_row30_col5, #T_ef05f_row31_col5, #T_ef05f_row32_col5, #T_ef

# %% [markdown]
# **[2.3] Remove unclear/ invalid attributes**

# %% [markdown]
# * Since definitions of "ftr" and "pfr" are unclear, the attributes will be eliminated from the analysis. 'ht' consists of various invalid values, the vairable will also be removed. The high cardinality involved in 'num' will be removed.

# %%
df_train = df_train.drop(['ftr', 'pfr', 'num', 'ht'], axis=1).reset_index(drop=True)
df_test = df_test.drop(['ftr', 'pfr', 'num', 'ht'], axis=1).reset_index(drop=True)

# %% [markdown]
# **Save a copy of data before cleaning**

# %%
df_train2 = df_train.copy()
df_test2 = df_test.copy()

# %% [markdown]
# **[2.4] Handle missing values**

# %%
#Visualize by heatmap
plt.figure(figsize=(10,6))
sns.heatmap(df_train2.isnull(), yticklabels=False, xticklabels=True, cbar=False, cmap='plasma')
plt.xticks(rotation=90)
plt.title('Missing values heatmap', size=14, color='grey')
plt.tight_layout()
plt.show()

# %%
#Count missing values
num=df_train2.select_dtypes(include = np.number).columns
num2=df_test2.select_dtypes(include = np.number).columns

cnt = df_train2[num].isna().sum()
per = ((cnt/df_train2.shape[0])*100).round(4)

cnt2 = df_test2[num2].isna().sum()
per2 = ((cnt2/df_test2.shape[0])*100).round(4)

missing_cnt = pd.concat([per, per2], axis=1, keys=['Missing_Percent__train', 'Missing_Percent__test'])
missing_cnt.sort_values(['Missing_Percent__train', 'Missing_Percent__test'], ascending=False)
# Out:
#                      Missing_Percent__train  Missing_Percent__test
# pick                                97.4109                99.0141
# Rec_Rank                            69.2458                71.1469
# dunks_ratio                         56.2401                54.6680
# mid_ratio                           18.3792                14.0241
# rim_ratio                           18.2312                12.9980
# rimmade                             12.3515                 4.9899
# rimmade_rimmiss                     12.3515                 4.9899
# midmade                             12.3515                 4.9899
# midmade_midmiss                     12.3515                 4.9899
# dunksmade                           12.3515                 4.9899
# dunksmiss_dunksmade                 12.3515                 4.9899
# ast_tov                              7.4370                10.8048
# drtg                                 0.0901                 0.0201
# adrtg                                0.0901                 0.0201
# dporpag                              0.0901                 0.0201
# stops                                0.0901                 0.0201
# bpm                                  0.0901                 0.0201
# obpm                                 0.0901                 0.0201
# dbpm                                 0.0901                 0.0201
# gbpm                                 0.0901                 0.0201
# ogbpm                                0.0901                 0.0201
# dgbpm                                0.0901                 0.0201
# mp                                   0.0772                 0.0000
# oreb                                 0.0772                 0.0000
# dreb                                 0.0772                 0.0000
# treb                                 0.0772                 0.0000
# ast                                  0.0772                 0.0000
# stl                                  0.0772                 0.0000
# blk                                  0.0772                 0.0000
# pts                                  0.0772                 0.0000
# GP                                   0.0000                 0.0000
# Min_per                              0.0000                 0.0000
# Ortg                                 0.0000                 0.0000
# usg                                  0.0000                 0.0000
# eFG                                  0.0000                 0.0000
# TS_per                               0.0000                 0.0000
# ORB_per                              0.0000                 0.0000
# DRB_per                              0.0000                 0.0000
# AST_per                              0.0000                 0.0000
# TO_per                               0.0000                 0.0000
# FTM                                  0.0000                 0.0000
# FTA                                  0.0000                 0.0000
# FT_per                               0.0000                 0.0000
# twoPM                                0.0000                 0.0000
# twoPA                                0.0000                 0.0000
# twoP_per                             0.0000                 0.0000
# TPM                                  0.0000                 0.0000
# TPA                                  0.0000                 0.0000
# TP_per                               0.0000                 0.0000
# blk_per                              0.0000                 0.0000
# stl_per                              0.0000                 0.0000
# porpag                               0.0000                 0.0000
# adjoe                                0.0000                 0.0000
# year                                 0.0000                 0.0000
# drafted                              0.0000                    NaN

# %% [markdown]
# * Since attributes dunks_ratio contain over 50% of missing values, the entire column will be dropped to avoid inappropriate imputation. Regarding pick and Rec_Rank, these features would be significant predictors. They will be replaced with zero and created binary features to distinguish.

# %%
df_train2 = df_train2.drop(['dunks_ratio'], axis=1)
df_test2 = df_test2.drop(['dunks_ratio'], axis=1)

# %% [markdown]
# **Pick and Rec_Rank - fill missing values and create encoded features**

# %%
df_train2['pick'] = df_train2['pick'].fillna(0)
df_test2['pick'] = df_test2['pick'].fillna(0)

df_train2['Rec_Rank'] = df_train2['Rec_Rank'].fillna(0)
df_test2['Rec_Rank'] = df_test2['Rec_Rank'].fillna(0)


# df_train2['Picked'] = (df_train2['pick'] > 0).astype(int)
# df_test2['Picked'] = (df_test2['pick'] > 0).astype(int)

# df_train2['Recruited'] = (df_train2['Rec_Rank'] > 0).astype(int)
# df_test2['Recruited'] = (df_test2['Rec_Rank'] > 0).astype(int)

# %% [markdown]
# **Convert pick and recruit_rank into binary features**

# %%
df_train2['Picked'] = df_train2['pick'].apply(lambda x:1 if x>0 else 0)
df_test2['Picked'] = df_test2['pick'].apply(lambda x:1 if x>0 else 0)

df_train2['Recruited'] = df_train2['Rec_Rank'].apply(lambda x:1 if x>0 else 0)
df_test2['Recruited'] = df_test2['Rec_Rank'].apply(lambda x:1 if x>0 else 0)

# %%
df_train2.describe()
# Out:
#                  GP       Min_per          Ortg           usg           eFG  \
# count  46618.000000  46618.000000  46618.000000  46618.000000  46618.000000
# mean      23.542988     37.339013     91.784360     18.164578     44.424392
# std       10.076829     28.019801     30.235568      6.181982     18.026404
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%       17.000000      9.600000     83.900000     14.600000     40.000000
# 50%       28.000000     35.900000     97.000000     18.100000     47.500000
# 75%       31.000000     62.200000    106.800000     21.800000     53.000000
# max       41.000000     98.000000    834.000000     50.000000    150.000000
#
#              TS_per       ORB_per       DRB_per       AST_per        TO_per  \
# count  46618.000000  46618.000000  46618.000000  46618.000000  46618.000000
# mean      47.571397      5.654071     12.575102     10.923008     20.535915
# std       17.217909      9.985025     11.041089      9.430012     12.210669
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       43.770000      1.900000      8.400000      4.600000     14.900000
# 50%       50.720000      4.500000     11.800000      9.100000     19.300000
# 75%       55.947500      8.200000     15.900000     15.200000     24.700000
# max      150.000000   1576.600000   1385.000000    100.000000    100.000000
#
#                 FTM           FTA        FT_per         twoPM         twoPA  \
# count  46618.000000  46618.000000  46618.000000  46618.000000  46618.000000
# mean      33.357909     47.887597      0.579193     41.521408     85.960444
# std       37.306108     50.190318      0.266445     43.820264     85.556152
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        4.000000      7.000000      0.500000      5.000000     13.000000
# 50%       20.000000     32.000000      0.657000     27.000000     60.000000
# 75%       51.000000     74.000000      0.750000     65.000000    136.000000
# max      312.000000    374.000000      1.000000    311.000000    615.000000
#
#            twoP_per           TPM           TPA        TP_per       blk_per  \
# count  46618.000000  46618.000000  46618.000000  46618.000000  46618.000000
# mean       0.424809     15.379274     44.595264      0.224779      1.877063
# std        0.191180     21.482081     57.557171      0.191479      6.271323
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.371000      0.000000      1.000000      0.000000      0.000000
# 50%        0.457000      4.000000     17.000000      0.273000      0.800000
# 75%        0.522000     24.000000     73.000000      0.357000      2.500000
# max        1.000000    147.000000    394.000000      1.000000   1072.000000
#
#             stl_per        porpag         adjoe          year      Rec_Rank  \
# count  46618.000000  46618.000000  46618.000000  46618.000000  46618.000000
# mean       1.731048      0.779567     89.277666   2013.528036     16.366700
# std        2.148502      1.340548     30.669615      2.873213     29.003012
# min        0.000000     -6.792410    -39.021300   2009.000000      0.000000
# 25%        0.900000     -0.173758     79.145350   2011.000000      0.000000
# 50%        1.500000      0.389350     94.498250   2014.000000      0.000000
# 75%        2.200000      1.490375    106.508750   2016.000000     23.000000
# max      128.300000      8.658190    678.942000   2018.000000    100.000000
#
#             ast_tov       rimmade  rimmade_rimmiss       midmade  \
# count  43151.000000  40860.000000     40860.000000  40860.000000
# mean       0.922210     27.779809        46.572614     14.853377
# std        0.691221     29.893780        47.108673     17.834037
# min        0.000000      0.000000         0.000000      0.000000
# 25%        0.448264      4.000000         8.000000      2.000000
# 50%        0.807717     18.000000        32.000000      8.000000
# 75%        1.250035     42.000000        72.000000     22.000000
# max       12.001200    238.000000       358.000000    222.000000
#
#        midmade_midmiss     rim_ratio     mid_ratio     dunksmade  \
# count     40860.000000  38119.000000  38050.000000  40860.000000
# mean         41.602619      0.562907      0.322901      3.774498
# std          45.221695      0.191550      0.170364      7.884873
# min           0.000000      0.000000      0.000000      0.000000
# 25%           6.000000      0.500000      0.250000      0.000000
# 50%          26.000000      0.579700      0.333300      0.000000
# 75%          62.000000      0.666700      0.400000      4.000000
# max         532.000000      1.000000      1.000000    122.000000
#
#        dunksmiss_dunksmade          pick          drtg         adrtg  \
# count         40860.000000  46618.000000  46576.000000  46576.000000
# mean              4.230470      0.860505    103.364709    103.513641
# std               8.631777      5.916821     10.569908     11.405002
# min               0.000000      0.000000  -1330.060000  -1292.020000
# 25%               0.000000      0.000000     99.093975     98.128300
# 50%               0.000000      0.000000    103.752000    103.864000
# 75%               4.000000      0.000000    108.316250    109.385000
# max             132.000000     60.000000    131.461000    144.685000
#
#             dporpag         stops           bpm          obpm          dbpm  \
# count  46576.000000  46576.000000  46576.000000  46576.000000  46576.000000
# mean       1.427313     82.521563     -2.518313     -1.900248     -0.618064
# std        1.057080     65.092602      7.701851      5.186198      4.415293
# min       -0.857238      0.043033    -88.479400    -92.593500    -57.459400
# 25%        0.521836     19.951825     -5.406862     -4.020425     -2.280647
# 50%        1.253835     75.980950     -1.829445     -1.357925     -0.577818
# 75%        2.152052    134.325500      1.403800      1.019898      1.127100
# max        5.800530    360.572000    685.313000    161.995000    523.319000
#
#                gbpm            mp         ogbpm         dgbpm          oreb  \
# count  46576.000000  46582.000000  46576.000000  46576.000000  46582.000000
# mean      -2.552051     16.949385     -2.088273     -0.463778      0.778630
# std        8.305566     10.633054      6.160620      3.303826      0.745045
# min     -242.523000      0.000000   -141.539000   -100.984000      0.000000
# 25%       -5.419053      7.266700     -4.463895     -1.747553      0.228600
# 50%       -1.807265     16.642900     -1.581525     -0.335180      0.550000
# 75%        1.395935     26.312500      1.018088      1.048375      1.129000
# max      269.508000     50.000000    225.485000     78.985500      5.933300
#
#                dreb          treb           ast           stl           blk  \
# count  46582.000000  46582.000000  46582.000000  46582.000000  46582.000000
# mean       1.867124      2.645755      1.066943      0.527743      0.283606
# std        1.464894      2.096319      1.170469      0.469654      0.422755
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.681800      1.000000      0.217400      0.157900      0.000000
# 50%        1.600000      2.235300      0.666700      0.419400      0.131600
# 75%        2.724100      3.806500      1.529000      0.793100      0.366700
# max       11.545500     14.533300     10.000000      4.000000      5.258100
#
#                 pts       drafted        Picked     Recruited
# count  46582.000000  46618.000000  46618.000000  46618.000000
# mean       5.732429      0.009524      0.025891      0.307542
# std        4.942544      0.097127      0.158813      0.461481
# min        0.000000      0.000000      0.000000      0.000000
# 25%        1.538500      0.000000      0.000000      0.000000
# 50%        4.428600      0.000000      0.000000      0.000000
# 75%        9.033050      0.000000      0.000000      1.000000
# max       29.968800      1.000000      1.000000      1.000000

# %% [markdown]
# * As some of the variables are right-skewed, the missing values will be replaced with the median.

# %% [markdown]
# **Fill missing values with median**

# %%
for col in df_train2.select_dtypes(include=np.number).columns:
    df_train2[col] = df_train2[col].fillna(df_train2[col].median())

for col in df_test2.select_dtypes(include=np.number).columns:
    df_test2[col] = df_test2[col].fillna(df_test2[col].median())

# %% [markdown]
# **Check if missing values are addressed**

# %%
num=df_train2.select_dtypes(include = np.number).columns
num2=df_test2.select_dtypes(include = np.number).columns

cnt = df_train2[num].isna().sum()
per = ((cnt/df_train2.shape[0])*100).round(4)

cnt2 = df_test2[num2].isna().sum()
per2 = ((cnt2/df_test2.shape[0])*100).round(4)

missing_cnt = pd.concat([per, per2], axis=1, keys=['Missing_Percent__train', 'Missing_Percent__test'])
missing_cnt.sort_values(['Missing_Percent__train', 'Missing_Percent__test'], ascending=False)
missing_cnt[missing_cnt['Missing_Percent__train']>0]
# Out:
# Empty DataFrame
# Columns: [Missing_Percent__train, Missing_Percent__test]
# Index: []

# %% [markdown]
# **[2.5] Handling outliers**

# %% [markdown]
# **Use boxplots to detect outliers**

# %%
#Iterate the list of variables to plot boxplots
numvar = df_train2.select_dtypes(include = np.number).columns
var_range = [(0, 8), (9, 18), (19, 28), (29, 38), (39, 48), (49, 60)]

fig, axes = plt.subplots(3, 2, figsize=(20,15))

for i, (a,b) in enumerate(var_range):
    var = numvar[a:b]
    data = [df_train2[col].dropna().values for col in var]
    ax = axes[i//2, i%2]
    ax.boxplot(data, vert=False, tick_labels=var)

fig.suptitle(f'Boxplot of variables (Train set)', size=20)
fig.supxlabel('Values')
fig.supylabel('Variables')
plt.tight_layout()
plt.show()

# %% [markdown]
# * Obviously, outliers are detected across multiple variables. Extreme outliers will highly distort the model performance and predictability, therefore they will be addressed by IQR method.

# %% [markdown]
# **Handling Outliers with IQR method**

# %%
#Train set
var = ['ORB_per', 'DRB_per', 'blk_per', 'drtg', 'adrtg']

for col in var:
    Q1 = df_train2[col].quantile(0.25)
    Q3 = df_train2[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_train2 = df_train2[(df_train2[col] >= lower_bound) & (df_train2[col] <= upper_bound)]

df_train2.describe(include='all')
# Out:
#          team   conf            GP       Min_per         Ortg           usg  \
# count   41276  41276  41276.000000  41276.000000  41276.00000  41276.000000
# unique    355     36           NaN           NaN          NaN           NaN
# top      Penn    A10           NaN           NaN          NaN           NaN
# freq      154   1616           NaN           NaN          NaN           NaN
# mean      NaN    NaN     24.282392     39.229169     92.44719     18.169634
# std       NaN    NaN      9.511186     27.763210     27.95672      5.865000
# min       NaN    NaN      1.000000      0.000000      0.00000      0.000000
# 25%       NaN    NaN     19.000000     12.700000     84.90000     14.700000
# 50%       NaN    NaN     28.000000     38.500000     97.10000     18.100000
# 75%       NaN    NaN     31.000000     63.800000    106.70000     21.800000
# max       NaN    NaN     41.000000     98.000000    834.00000     50.000000
#
#                  eFG        TS_per       ORB_per       DRB_per       AST_per  \
# count   41276.000000  41276.000000  41276.000000  41276.000000  41276.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       44.874331     48.106386      4.895230     11.603050     11.441281
# std        16.570441     15.857189      3.810372      5.373759      8.923157
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        40.600000     44.350000      1.800000      8.200000      5.400000
# 50%        47.500000     50.770000      4.100000     11.300000      9.800000
# 75%        52.700000     55.790000      7.500000     15.000000     15.900000
# max       150.000000    150.000000     17.600000     26.900000    100.000000
#
#               TO_per           FTM           FTA        FT_per         twoPM  \
# count   41276.000000  41276.000000  41276.000000  41276.000000  41276.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       20.585721     34.895678     49.601027      0.600705     42.159584
# std        11.379370     37.585701     50.106389      0.253164     42.828758
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        15.100000      5.000000      9.000000      0.516000      7.000000
# 50%        19.300000     22.000000     34.000000      0.667000     29.000000
# 75%        24.600000     53.000000     76.000000      0.761000     66.000000
# max       100.000000    312.000000    374.000000      1.000000    311.000000
#
#                twoPA      twoP_per           TPM           TPA        TP_per  \
# count   41276.000000  41276.000000  41276.000000  41276.000000  41276.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       88.224319      0.427657     17.101827     49.501066      0.242245
# std        84.469438      0.177985     22.098891     58.940613      0.183673
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        17.000000      0.376000      0.000000      2.000000      0.000000
# 50%        64.000000      0.455000      7.000000     24.000000      0.290000
# 75%       138.000000      0.517000     27.000000     81.000000      0.363000
# max       615.000000      1.000000    147.000000    394.000000      1.000000
#
#              blk_per       stl_per     yr        porpag         adjoe  \
# count   41276.000000  41276.000000  41062  41276.000000  41276.000000
# unique           NaN           NaN      7           NaN           NaN
# top              NaN           NaN     Jr           NaN           NaN
# freq             NaN           NaN  11092           NaN           NaN
# mean        1.307147      1.687235    NaN      0.813217     89.986361
# std         1.499922      1.170708    NaN      1.355988     28.553654
# min         0.000000      0.000000    NaN     -6.792410    -39.021300
# 25%         0.000000      1.000000    NaN     -0.160896     80.154725
# 50%         0.800000      1.600000    NaN      0.434837     94.727100
# 75%         2.000000      2.300000    NaN      1.552260    106.287500
# max         6.100000     28.000000    NaN      8.658190    678.942000
#
#                 year   type      Rec_Rank       ast_tov       rimmade  \
# count   41276.000000  41276  41276.000000  41276.000000  41276.000000
# unique           NaN      1           NaN           NaN           NaN
# top              NaN    all           NaN           NaN           NaN
# freq             NaN  41276           NaN           NaN           NaN
# mean     2013.520738    NaN     16.176756      0.959321     26.576025
# std         2.874594    NaN     28.728715      0.671656     27.369180
# min      2009.000000    NaN      0.000000      0.000000      0.000000
# 25%      2011.000000    NaN      0.000000      0.500150      6.000000
# 50%      2014.000000    NaN      0.000000      0.812579     18.000000
# 75%      2016.000000    NaN     22.600000      1.266565     38.000000
# max      2018.000000    NaN    100.000000     12.001200    238.000000
#
#         rimmade_rimmiss       midmade  midmade_midmiss     rim_ratio  \
# count      41276.000000  41276.000000     41276.000000  41276.000000
# unique              NaN           NaN              NaN           NaN
# top                 NaN           NaN              NaN           NaN
# freq                NaN           NaN              NaN           NaN
# mean          45.236578     14.420826        40.909245      0.562844
# std           43.623728     16.853504        42.708868      0.167651
# min            0.000000      0.000000         0.000000      0.000000
# 25%           12.000000      3.000000        10.000000      0.500000
# 50%           32.000000      8.000000        26.000000      0.579700
# 75%           66.000000     20.000000        58.000000      0.637900
# max          358.000000    222.000000       532.000000      1.000000
#
#            mid_ratio     dunksmade  dunksmiss_dunksmade          pick  \
# count   41276.000000  41276.000000         41276.000000  41276.000000
# unique           NaN           NaN                  NaN           NaN
# top              NaN           NaN                  NaN           NaN
# freq             NaN           NaN                  NaN           NaN
# mean        0.325704      2.819387             3.174750      0.786026
# std         0.149940      6.341450             6.975851      5.670202
# min         0.000000      0.000000             0.000000      0.000000
# 25%         0.274500      0.000000             0.000000      0.000000
# 50%         0.333300      0.000000             0.000000      0.000000
# 75%         0.386600      3.000000             3.000000      0.000000
# max         1.000000     99.000000           105.000000     60.000000
#
#                 drtg         adrtg       dporpag         stops           bpm  \
# count   41276.000000  41276.000000  41276.000000  41276.000000  41276.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean      104.245385    104.344978      1.459323     85.145234     -2.575603
# std         6.279304      7.594576      1.030187     63.433952      5.991332
# min        86.690000     83.003300      0.002508      0.043486    -60.047800
# 25%        99.957575     99.028950      0.589522     25.729400     -5.301815
# 50%       104.258000    104.437500      1.306695     80.719650     -1.924590
# 75%       108.591250    109.670250      2.171387    135.921750      1.149853
# max       121.814000    125.786000      5.340040    299.610000     27.439100
#
#                 obpm          dbpm          gbpm            mp         ogbpm  \
# count   41276.000000  41276.000000  41276.000000  41276.000000  41276.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       -1.679996     -0.895692     -2.596475     17.706624     -1.959332
# std         4.505743      2.648985      7.209597     10.478583      5.495239
# min       -43.195100    -26.661400   -142.114000      0.000000   -106.262000
# 25%        -3.780743     -2.303060     -5.357470      8.333300     -4.275498
# 50%        -1.228985     -0.729527     -1.881095     17.645200     -1.506645
# 75%         1.095600      0.777794      1.216110     26.970800      1.019082
# max        42.552200     10.809800    269.508000     40.066700    225.485000
#
#                dgbpm          oreb          dreb          treb           ast  \
# count   41276.000000  41276.000000  41276.000000  41276.000000  41276.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       -0.637230      0.754079      1.874655      2.628795      1.155548
# std         2.523313      0.707437      1.400116      1.992482      1.199131
# min       -40.672400      0.000000      0.000000      0.000000      0.000000
# 25%        -1.782725      0.233300      0.750000      1.069000      0.272700
# 50%        -0.460487      0.545500      1.655200      2.275900      0.766700
# 75%         0.820433      1.083300      2.718800      3.757600      1.647100
# max        44.022500      4.939400      8.771400     13.069000     10.000000
#
#                  stl           blk           pts  \
# count   41276.000000  41276.000000  41276.000000
# unique           NaN           NaN           NaN
# top              NaN           NaN           NaN
# freq             NaN           NaN           NaN
# mean        0.556970      0.223855      5.994325
# std         0.472476      0.285047      4.949057
# min         0.000000      0.000000      0.000000
# 25%         0.181800      0.000000      1.800000
# 50%         0.454500      0.121200      4.789500
# 75%         0.827600      0.314300      9.314300
# max         4.000000      2.069000     29.968800
#
#                                    player_id       drafted        Picked  \
# count                                  41276  41276.000000  41276.000000
# unique                                 18814           NaN           NaN
# top     c6a43e58-d8ad-478f-bbc0-dbc880e29142           NaN           NaN
# freq                                       6           NaN           NaN
# mean                                     NaN      0.008165      0.023355
# std                                      NaN      0.089989      0.151030
# min                                      NaN      0.000000      0.000000
# 25%                                      NaN      0.000000      0.000000
# 50%                                      NaN      0.000000      0.000000
# 75%                                      NaN      0.000000      0.000000
# max                                      NaN      1.000000      1.000000
#
#            Recruited
# count   41276.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        0.307539
# std         0.461480
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %% [markdown]
# ### 3. Explore variables

# %% [markdown]
# **[3.1] Target variable**

# %%
draft_prob = df_train2.drafted.value_counts(normalize=True)
fig, ax = plt.subplots()
draft_prob.plot(kind='bar', ax=ax).set_title('Target proportion')
ax.set_xlabel('Drafted')
ax.set_ylabel('Probability')
ax.set_xticklabels([0,1], rotation=0)
ax.grid(False)
plt.show()

# %%
#Games played by year
ax=sns.histplot(df_train2['GP'][df_train2['drafted']==0], edgecolor='white', kde=True, color='skyblue')
ax=sns.histplot(df_train2['GP'][df_train2['drafted']==1], edgecolor='white', kde=True, color='orange')
ax.legend(['drafted 0', 'drafted 1'])
ax.set_title('Number of games played by draft')
plt.show()

# %% [markdown]
# * Players who played more games seem to have higher chances of being drafted.

# %%
ax=sns.kdeplot(df_train2['mp'][df_train2['drafted']==0], color='Skyblue', fill=True)
ax=sns.kdeplot(df_train2['mp'][df_train2['drafted']==1], color='Orange', fill=True)
ax.legend(['drafted 0', 'drafted 1'])
ax.set_title('Minutes played by by draft')
# Out:
# Text(0.5, 1.0, 'Minutes played by by draft')

# %% [markdown]
# * Players who played more minutes in the season tend to have higher chances of being drafted.

# %% [markdown]
# **Categorical variables**

# %%
df_train2['type'].value_counts()
# Out:
# type
# all    41276
# Name: count, dtype: int64

# %% [markdown]
# **Count unique values of student's year of study**

# %%
df_train2['yr'].value_counts()
# Out:
# yr
# Jr      11092
# Fr      10688
# So       9686
# Sr       9591
# 0           3
# 57.1        1
# 42.9        1
# Name: count, dtype: int64

# %% [markdown]
# * There is only one 'type' in the dataset. In other words, it is not useful for prediction and, therefore, will be dropped.
# * Regarding the student's year of study ('yr'), some numeric values were found in the data, which are invalid in this categorical variable. As the proportion is relatively small, those rows will be eliminated.

# %% [markdown]
# **Drop attribute 'type'**

# %%
df_train2 = df_train2.drop(['type'], axis=1)
df_test2 = df_test2.drop(['type'], axis=1)

# %% [markdown]
# **Remove invalid values existing in student's year of study**

# %%
#Transform 'yr' type to string and filter the invalid values
df_train2['yr'] = df_train2['yr'].astype(str)
df_test2['yr'] = df_test2['yr'].astype(str)

#Fill missing values 
df_train2['yr'] = df_train2['yr'].replace(['nan', '0', '57.1', '42.9'], np.nan)
df_train2['yr'] = df_train2['yr'].ffill()
df_test2['yr'] = df_test2['yr'].replace(['nan', '0'], np.nan)
df_test2['yr'] = df_test2['yr'].ffill()

# %%
print("Train:", df_train.shape)
print("Test:", df_test.shape)
# Out:
# Train: (46618, 60)
# Test: (4970, 59)

# %% [markdown]
# **Check if the invalid values are addressed**

# %%
print("Train:\n", df_train2['yr'].value_counts())
print("\nTest:\n", df_test2['yr'].value_counts())
# Out:
# Train:
#  yr
# Jr    11151
# Fr    10788
# So     9715
# Sr     9622
# Name: count, dtype: int64
#
# Test:
#  yr
# Fr    1328
# Jr    1318
# So    1233
# Sr    1091
# Name: count, dtype: int64

# %% [markdown]
# ### 4. Prepare Data

# %% [markdown]
# **[4.1] Create a copy of dataframe**

# %%
df_train_cleaned = df_train2.copy()
df_test_cleaned = df_test2.copy()

# %% [markdown]
# **[4.2] Extract the target from dataframe**

# %%
y_data = df_train_cleaned.pop('drafted')

# %%
#Frequency of target variable
y_data.value_counts(normalize=True)
# Out:
# drafted
# 0.0    0.991835
# 1.0    0.008165
# Name: proportion, dtype: float64

# %% [markdown]
# **[4.3] Create a list of numeric and categorical variables respectively**

# %%
num_cols = list(df_train_cleaned.select_dtypes('number').columns)
cat_cols = list(set(df_train_cleaned.columns) - set(num_cols))

num_cols2 = list(df_test_cleaned.select_dtypes('number').columns)
cat_cols2 = list(set(df_test_cleaned.columns) - set(num_cols2))

# %% [markdown]
# **[4.4] Import scaler and encoding**

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %% [markdown]
# **[4.65 Encoding categorical variable**

# %%
ohe = OneHotEncoder(sparse_output=False, drop='first')

#Transform the column
features_train = ohe.fit_transform(df_train_cleaned[['yr']])
features_test = ohe.transform(df_test_cleaned[['yr']])

# %%
#Convert to dataframes
features_train = pd.DataFrame(features_train, columns=ohe.get_feature_names_out())
features_test = pd.DataFrame(features_test, columns=ohe.get_feature_names_out())

# %% [markdown]
# **[4.6] Scaling and fit transform numeric features**

# %%
scaler = StandardScaler()

# %%
#Fit transform
features_train[num_cols] = scaler.fit_transform(df_train_cleaned[num_cols])
features_test[num_cols2] = scaler.transform(df_test_cleaned[num_cols2])

# %% [markdown]
# ### 5. Split the dataset

# %%
X_train = features_train
X_test = features_test

# %% [markdown]
# **Import package and split the data**

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_data, test_size=0.2, random_state=8)

# %% [markdown]
# **Dimension**

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (33020, 58)
# (8256, 58)
# (4970, 58)

# %% [markdown]
# **Target proportion**

# %%
print(y_train.value_counts(normalize=True))
print(y_val.value_counts(normalize=True))
# Out:
# drafted
# 0.0    0.991763
# 1.0    0.008237
# Name: proportion, dtype: float64
# drafted
# 0.0    0.992127
# 1.0    0.007873
# Name: proportion, dtype: float64

# %% [markdown]
# ### 6. Feature Engineering

# %% [markdown]
# **[6.1] Correlation**

# %%
features = X_train
corr_matrix = features.corr().round(2)
sign_corr_matrix = corr_matrix[(corr_matrix>=0.9) | (corr_matrix <=-0.9)]

import plotly.express as px
#Create correlation heatmap
fig = px.imshow(sign_corr_matrix, x=sign_corr_matrix.columns, y=sign_corr_matrix.columns,
                zmin=-1, zmax=1, color_continuous_scale='RdYlBu',title='Features correlation', text_auto=True)

#Update the layout
fig.update_xaxes(tickangle=45)
fig.show()
# Out:
# <div>                            <div id="e6bce9de-36e5-4fa4-ba0b-b04d98f80ee6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6bce9de-36e5-4fa4-ba0b-b04d98f80ee6")) {                    Plotly.newPlot(                        "e6bce9de-36e5-4fa4-ba0b-b04d98f80ee6",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["yr_Jr","yr_So","yr_Sr","GP","Min_per","Ortg","usg","eFG","TS_per","ORB_per","DRB_per","AST_per","TO_per","FTM","FTA","FT_per","twoPM","twoPA","twoP_per","TPM","TPA","TP_per","blk_per","stl_per","porpag","adjoe","year","Rec_Rank","ast_tov","rimmade","rimmade_rimmiss","midmade","midmade_midmiss","rim_ratio","mid_ratio","dunksmade","dunksmiss_dunksmade","pick","drtg","adrtg","dporpag","stops","bpm","obpm","dbpm","gbpm","mp","ogbpm","dgbpm","oreb","dreb","treb","ast","stl","blk","pts","Picked","Recruited"],"y":["yr_Jr","yr_So","yr_Sr","GP","Min_per","Ortg","usg","eFG","TS_per","ORB_per","DRB_per","AST_per","TO_per","FTM","FTA","FT_per","twoPM","twoPA","twoP_per","TPM","TPA","TP_per","blk_per","stl_per","porpag","adjoe","year","Rec_Rank","ast_tov","rimmade","rimmade_rimmiss","midmade","midmade_midmiss","rim_ratio","mid_ratio","dunksmade","dunksmiss_dunksmade","pick","drtg","adrtg","dporpag","stops","bpm","obpm","dbpm","gbpm","mp","ogbpm","dgbpm","oreb","dreb","treb","ast","stl","blk","pts","Picked","Recruited"],"z":[[1.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,1.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,1.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,1.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,1.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.96,null,null,null,null,0.96,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,1.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.96,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,1.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,1.0,0.94,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],[null,null,null,null,null,null,null,0.94,1.0,null, ...

# %% [markdown]
# **[6.2] Drop collinear and insignificant features**

# %%
to_drop = ['FTM', 'FTA', 'twoPM', 'twoPA', 'TPM', 'TPA', 'rimmade', 'rimmade_rimmiss',
          'midmade', 'midmade_midmiss', 'Picked', 'Recruited']

# %%
X_train = X_train.drop(X_train[to_drop], axis=1)
X_val = X_val.drop(X_val[to_drop], axis=1)
X_test = X_test.drop(X_test[to_drop], axis=1)

X_train.columns
# Out:
# Index(['yr_Jr', 'yr_So', 'yr_Sr', 'GP', 'Min_per', 'Ortg', 'usg', 'eFG',
#        'TS_per', 'ORB_per', 'DRB_per', 'AST_per', 'TO_per', 'FT_per',
#        'twoP_per', 'TP_per', 'blk_per', 'stl_per', 'porpag', 'adjoe', 'year',
#        'Rec_Rank', 'ast_tov', 'rim_ratio', 'mid_ratio', 'dunksmade',
#        'dunksmiss_dunksmade', 'pick', 'drtg', 'adrtg', 'dporpag', 'stops',
#        'bpm', 'obpm', 'dbpm', 'gbpm', 'mp', 'ogbpm', 'dgbpm', 'oreb', 'dreb',
#        'treb', 'ast', 'stl', 'blk', 'pts'],
#       dtype='object')

# %% [markdown]
# **Save the processed data**

# %%
X_train.to_csv('../data/processed/X_train2.csv', index=False)
X_val.to_csv('../data/processed/X_val2.csv', index=False)
X_test.to_csv('../data/processed/X_test2.csv', index=False)
y_train.to_csv('../data/processed/y_train2.csv', index=False)
y_val.to_csv('../data/processed/y_val2.csv', index=False)

# %% [markdown]
# ### 7. Train XGBoost Model - Hyperparameter Tuning with RandomSearchCV

# %% [markdown]
# **[7.1] Instantiate and fit the model**

# %%
from xgboost import XGBClassifier
xg = XGBClassifier(subsample=0.9, random_state=8)

# %% [markdown]
# **[7.2] Parameters dictionary**

# %%
from scipy.stats import randint

param_ran = {
    'gamma': randint(0, 10),
    'max_depth': randint(1, 10),
    'scale_pos_weight': randint(1, 100),
    'max_delta_step': randint(1, 10)
}

# %% [markdown]
# **[7.3] Instantiate and fit the hyperparameters wit Stratified KFold**

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=8)
ransearch = RandomizedSearchCV(xg, param_ran, cv=skf, random_state=8)

# %%
ransearch.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=8, shuffle=True),
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importanc...
#                    param_distributions={'gamma': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000022010E1D190>,
#                                         'max_delta_step': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000022011E63310>,
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000022011E62190>,
#                                         'scale_pos_weight': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000022011E632D0>},
#                    random_state=8)

# %% [markdown]
# **[7.4] Display the best set of parameters**

# %%
ransearch.best_params_
# Out:
# {'gamma': 3, 'max_delta_step': 5, 'max_depth': 2, 'scale_pos_weight': 6}

# %% [markdown]
# **[7.5] Evaluation metrics for hyperparameters**

# %%
ransearch.best_score_
# Out:
# np.float64(0.9947304663840096)

# %%
print("RanCV_Train:", f'{ransearch.score(X_train, y_train):.4f}')
print("RanCV_val:", f'{ransearch.score(X_val, y_val):.4f}')
# Out:
# RanCV_Train: 0.9981
# RanCV_val: 0.9961

# %% [markdown]
# **[7.6] Make prediction on training data**

# %%
y_train_pred = ransearch.best_estimator_.predict_proba(X_train)[:, 1]
y_val_pred = ransearch.best_estimator_.predict_proba(X_val)[:, 1]

# %% [markdown]
# **[7.7] Performance metric - AUROC**

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc

# %%
print("Train - AUROC:\n", f'{roc_auc_score(y_train, y_train_pred):.4f}')
print("Val - AUROC:\n", f'{roc_auc_score(y_val, y_val_pred):.4f}')
# Out:
# Train - AUROC:
#  0.9999
# Val - AUROC:
#  0.9987

# %% [markdown]
# **Plot the AUROC curve**

# %%
fpr, tpr, thresholds = roc_curve(y_val, y_val_pred) 
roc_auc = auc(fpr, tpr)
plt.figure()  
plt.plot(fpr, tpr, label='Val - ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', label='Worst case')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('(Validation) ROC Curve for NBA Draft')
plt.legend()
plt.show()

# %% [markdown]
# **[7.8] Predict on test data**

# %%
y_test_pred = ransearch.best_estimator_.predict_proba(X_test)[:, 1]

#Dataframe for pred result
y_pred = pd.read_csv('../data/interim/y_test.csv')
y_pred.loc[:, 'drafted'] = y_test_pred

print(y_pred.describe().round(5))

y_pred = pd.DataFrame(y_pred)

#Save the result to CSV file
y_pred.to_csv('../data/external/at1_pred_week3.9.csv', index=False)
# Out:
#           drafted
# count  4970.00000
# mean      0.00610
# std       0.06863
# min       0.00000
# 25%       0.00000
# 50%       0.00000
# 75%       0.00003
# max       0.99832

# %% [markdown]
# ### 8. Feature Importance

# %%
feature = ransearch.best_estimator_.feature_importances_

# %%
#Dataframe of feature importance
feat_imp_rf_df = pd.DataFrame(
    {'feature': X_train.columns,
     'feature_importance': feature})

# %%
#Sort the dataframe
feat_imp_rf_df = feat_imp_rf_df.sort_values('feature_importance', ascending=False).reset_index(drop=True)
feat_imp_rf_df
# Out:
#                 feature  feature_importance
# 0                  pick            0.501851
# 1                porpag            0.109889
# 2                   pts            0.049233
# 3               dporpag            0.039897
# 4                    mp            0.026030
# 5                 yr_Sr            0.018546
# 6              Rec_Rank            0.016073
# 7   dunksmiss_dunksmade            0.015298
# 8                 stops            0.014637
# 9                   usg            0.009677
# 10            rim_ratio            0.008280
# 11              ORB_per            0.008196
# 12                  stl            0.007723
# 13                adjoe            0.007674
# 14               TO_per            0.007673
# 15                 obpm            0.007624
# 16                ogbpm            0.007115
# 17                   GP            0.007115
# 18                adrtg            0.006973
# 19                 Ortg            0.006532
# 20              blk_per            0.006492
# 21            dunksmade            0.006387
# 22                  ast            0.006384
# 23               FT_per            0.006353
# 24               TS_per            0.006333
# 25                  eFG            0.006315
# 26              stl_per            0.006068
# 27               TP_per            0.005657
# 28             twoP_per            0.005595
# 29              DRB_per            0.005553
# 30              Min_per            0.005516
# 31                  bpm            0.005485
# 32                 drtg            0.005470
# 33                 oreb            0.005454
# 34                 year            0.005140
# 35                 gbpm            0.005126
# 36              ast_tov            0.004941
# 37                dgbpm            0.004902
# 38                  blk            0.004830
# 39            mid_ratio            0.004818
# 40                 dreb            0.004492
# 41              AST_per            0.004077
# 42                 dbpm            0.002576
# 43                yr_Jr            0.000000
# 44                yr_So            0.000000
# 45                 treb            0.000000

# %%
#Visualize the feature importance
import altair as alt

alt.Chart(feat_imp_rf_df).mark_bar().encode(
    x='feature_importance',
    y=alt.Y("feature", sort='-x'),
    tooltip=['feature','feature_importance']
)
# Out:
# alt.Chart(...)
