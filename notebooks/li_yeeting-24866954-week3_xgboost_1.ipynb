# %% [markdown]
# ### 1. Load the dataset

# %% [markdown]
# **[1.1] Automatic reload modules**

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# **[1.2] Import packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from joblib import dump

# %% [markdown]
# **[1.3] Load the datasets**

# %%
X_train = pd.read_csv('../data/processed/X_train.csv')
X_val   = pd.read_csv('../data/processed/X_val.csv')
X_test  = pd.read_csv('../data/processed/X_test.csv')
y_train = pd.read_csv('../data/processed/y_train.csv')
y_val   = pd.read_csv('../data/processed/y_val.csv')
y_test = pd.read_csv('../data/interim/y_test.csv')

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (33001, 58)
# (8251, 58)
# (4970, 58)

# %%
y_train = y_train.values.ravel()
y_val = y_val.values.ravel()

# %% [markdown]
# ### 2. Train XGBoost Default Model

# %% [markdown]
# **[2.1] Instantiate and fit the model**

# %%
from xgboost import XGBClassifier
xg = XGBClassifier(random_state=8)

# %%
xg.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=8, ...)

# %% [markdown]
# **[2.2] Make prediction on training data**

# %%
y_train_pred = xg.predict_proba(X_train)[:, 1]
y_val_pred = xg.predict_proba(X_val)[:, 1]

# %% [markdown]
# **[2.3] Performance metric - AUROC**

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc

# %%
print("Train - AUROC:\n", f'{roc_auc_score(y_train, y_train_pred):.4f}')
print("Val - AUROC:\n", f'{roc_auc_score(y_val, y_val_pred):.4f}')
# Out:
# Train - AUROC:
#  1.0000
# Val - AUROC:
#  0.9982

# %% [markdown]
# **Plot the AUROC curve**

# %%
fpr, tpr, thresholds = roc_curve(y_val, y_val_pred) 
roc_auc = auc(fpr, tpr)
plt.figure()  
plt.plot(fpr, tpr, label='Val - ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', label='Worst case')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('(Validation) ROC Curve for NBA Draft')
plt.legend()
plt.show()

# %% [markdown]
# **[2.4] Predict on test data**

# %%
y_test_pred = xg.predict_proba(X_test)[:, 1]

#Dataframe for pred result
y_pred = y_test
y_pred.loc[:, 'drafted'] = y_test_pred

print(y_pred.describe().round(5))

y_pred = pd.DataFrame(y_pred)

#Save the result to CSV file
y_pred.to_csv('../data/external/at1_pred_week3.3.csv', index=False)
# Out:
#           drafted
# count  4970.00000
# mean      0.00453
# std       0.06194
# min       0.00000
# 25%       0.00000
# 50%       0.00000
# 75%       0.00000
# max       0.99975

# %% [markdown]
# ### 3. Feature Importance

# %%
feature = xg.feature_importances_

# %%
#Dataframe of feature importance
feat_imp_rf_df = pd.DataFrame(
    {'feature': X_train.columns,
     'feature_importance': feature})

# %%
#Sort the dataframe
feat_imp_rf_df = feat_imp_rf_df.sort_values('feature_importance', ascending=False).reset_index(drop=True)
feat_imp_rf_df
# Out:
#                 feature  feature_importance
# 0                  pick            0.369172
# 1                   pts            0.128595
# 2                 yr_Sr            0.047700
# 3                porpag            0.038276
# 4               dporpag            0.027501
# 5              Rec_Rank            0.025647
# 6                 yr_Jr            0.020781
# 7                   FTA            0.015088
# 8                 yr_So            0.014002
# 9                 twoPM            0.013195
# 10              rimmade            0.012951
# 11                   GP            0.012815
# 12             twoP_per            0.011598
# 13      midmade_midmiss            0.010911
# 14                adjoe            0.010747
# 15                twoPA            0.010000
# 16                 Ortg            0.008952
# 17              stl_per            0.008700
# 18                stops            0.008578
# 19               FT_per            0.008064
# 20      rimmade_rimmiss            0.008048
# 21              midmade            0.008047
# 22            rim_ratio            0.008000
# 23                adrtg            0.007807
# 24                  stl            0.007673
# 25              Min_per            0.007668
# 26                  usg            0.007628
# 27  dunksmiss_dunksmade            0.007465
# 28                 oreb            0.007415
# 29                  TPM            0.006808
# 30            dunksmade            0.006788
# 31                  bpm            0.006584
# 32                  ast            0.006033
# 33                 year            0.005818
# 34                 drtg            0.005761
# 35              ast_tov            0.005311
# 36                 dreb            0.005123
# 37               TO_per            0.005107
# 38               TP_per            0.005057
# 39              DRB_per            0.004938
# 40                 obpm            0.004817
# 41              AST_per            0.004772
# 42                   mp            0.004761
# 43              ORB_per            0.004749
# 44               TS_per            0.004632
# 45                  blk            0.004381
# 46                  FTM            0.004218
# 47                 gbpm            0.004206
# 48                 dbpm            0.004068
# 49                  TPA            0.004068
# 50                  eFG            0.003569
# 51                ogbpm            0.003507
# 52            mid_ratio            0.003473
# 53                dgbpm            0.003311
# 54              blk_per            0.003162
# 55                 treb            0.001952
# 56               Picked            0.000000
# 57            Recruited            0.000000

# %%
#Visualize the feature importance
import altair as alt

alt.Chart(feat_imp_rf_df).mark_bar().encode(
    x='feature_importance',
    y=alt.Y("feature", sort='-x'),
    tooltip=['feature','feature_importance']
)
# Out:
# alt.Chart(...)

# %% [markdown]
# **In the future experiments, hyperparameter tuning and feature engineering will be conducted to address overfitting issues.**
